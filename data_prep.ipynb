# %% [markdown]
# # Translation and Merging

# %% [markdown]
# Each data file is in a different language. We need to translate them into English before concatenation.
# First, we'll examine the headers

# %%
import pandas as pd

# Load the survey data files
file_paths = {
    'English': 'data/en.csv',
    'Bengali': 'data/bengali.csv',
    'Korean': 'data/kr.csv',
    'Vietnamese': 'data/vi.csv'
}

# Read the headers of each file
dfs = {}
headers = {}
for language, file_path in file_paths.items():
    df = pd.read_csv(file_path)  # Read only headers
    dfs[language] = df
    headers[language] = df.columns.tolist()

headers
# Out:
# {'English': ['Timestamp',
#   'What is your age group?',
#   'What is your gender?',
#   'What is the highest level of education you have completed?',
#   'Which category best describes your occupation?',
#   'On average, how many days per week do you exercise for at least 30 (or under 30 mins but high intensity) minutes? ',
#   'On average, how many hours per day do you use electronic devices such as smartphones, laptops, televisions, etc.? ',
#   'On average, how much time do you usually spend on phone / computers before sleep?',
#   '(Optional) What is your height in centimeters?',
#   '(Optional) What is your weight in kilograms?',
#   'On average, what time do you typically go to bed at night?',
#   'On average, what time do you typically wake up in the morning?',
#   'On average, how long does it take you to fall asleep at night?',
#   'On average, how long is your typical daytime nap?',
#   'On average, how many hours do you sleep per 24-hour period?',
#   'How would you rate your overall sleep quality?',
#   'How often do you experience sleep disturbances such as waking up during the night or having restless sleep?',
#   'Do you take any medication to help you sleep?',
#   'Your email address'],
#  'Bengali': ['Timestamp',
#   'Username',
#   'আপনার বয়স কত?*',
#   'আপনার লিঙ্গ কি? *',
#   'আপনার শিক্ষাগত যোগ্যতা কি? *\n',
#   'আপনার পেশা কি? *',
#   'গড়ে সপ্তাহে কয়দিন আপনি কমপক্ষে ৩০ মিনিট বা তার চেয়ে বেশি সময়ের জন্য ব্যায়াম করেন? *',
#   'গড়ে আপনি কত ঘণ্টা ইলেকট্রনিক ডিভাইস ব্যবহার করেন, যেমন স্মার্টফোন, ল্যাপটপ, টেলিভিশন, ইত্যাদি? ',
#   'গড়ে আপনি ঘুমানোর আগে ফোনে / ল্যপটপে কতটুকু সময় অতিবাহিত করেন?',
#   '(ঐচ্ছিক) আপনার উচ্চতা কত? (সে.মি. এককে)',
#   '(ঐচ্ছিক) আপনার ওজন কত? (কেজি তে)',
#   'রাতে সাধারনত কখন ঘুমাতে যান?',
#   'সাধারনত আপনি সকালে কখন ঘুম থেকে উঠেন?',
#   'সাধারনত শোয়ার কতক্ষনের মধ্যে আপনার ঘুম চলে আসে?',
#   'আপনি কি দিনের বেলা সামান্য ঘুমিয়ে নেন? যদি উত্তর হ্যা হয়, তাহলে তা কতক্ষন?',
#   'সব মিলিয়ে গড়ে আপনি ২৪ ঘণ্টার মধ্যে কত ঘণ্টা ঘুমান?',
#   'আপনার সামগ্রীক ঘুমের মান কেমন থাকে? ',
#   'আপনি কি পরিমান ঘুমের মধ্য বিঘ্নতা পরিলক্ষন করেন, যেমন রাতে ঘুম ভেঙ্গে যাওয়া বা খুব হালকা ঘুম?',
#   'আপনি কি ঘুমের জন্য কোন ঔষধ সেবন করেন?',
#   'আপনার ইমেল ঠিকানা'],
#  'Korean': ['Timestamp',
#   '귀하의 나이는 어떻게 되십니까?',
#   '귀하의 성별은 무엇입니까?',
#   '귀하의 최종 학력은 무엇입니까?',
#   '귀하의 직업은 무엇입니까?',
#   '일주일에 평균 며칠 동안 적어도 30분 이상 운동을 하십니까?',
#   '하루 평균 스마트폰, 노트북, TV 등 전자기기를 사용하는 시간이 얼마나 됩니까?',
#   '자기 전 전화/컴퓨터를 보는 시간이 일반적으로 얼마나 됩니까?',
#   '(선택 사항) 키는 센티미터로 몇이에요?',
#   '(선택 사항) 몸무게는 킬로그램으로 몇이에요?',
#   '보통 밤 몇 시에 잠자리에 드십니까?',
#   '보통 아침 몇 시에 일어나십니까? ',
#   '보통 밤에 잠든 후 대략 얼마나 걸리십니까?',
#   '일반적으로 낮잠 시간이 얼마나 됩니까?',
#   '24시간 기준 일일 평균 수면 시간이 얼마나 됩니까?',
#   '전체적인 수면 질을 어떻게 평가하십니까?',
#   '아침에 자주 깨는 등 수면 장애 증상이 얼마나 자주 있습니까?',
#   '수면 약을 복용하십니까?',
#   '귀하의 이메일 주소'],
#  'Vietnamese': ['Timestamp',
#   'Bạn bao nhiêu tuổi?',
#   'Giới tính của bạn? ',
#   'Trình độ học vấn cao nhất của bạn? ',
#   'Nghề nghiệp của bạn?',
#   'Trung bình mỗi tuần bạn tập thể dục ít nhất 30 phút (hoặc dưới 30p nhưng cường độ cao) bao nhiêu ngày?',
#   'Trung bình mỗi ngày bạn dùng các thiết bị điện tử như điện thoại thông minh, máy tính xách tay, ti vi, v.v. bao nhiêu giờ?',
#   'Trung bình bạn dành bao nhiêu thời gian sử dụng điện thoại/máy tính trước khi đi ngủ? ',
#   '(Không bắt buộc) Chiều cao của bạn là bao nhiêu cm?',
#   '(Không bắt buộc) Cân nặng của bạn là bao nhiêu kg?',
#   'Thông thường bạn đi ngủ vào lúc mấy giờ tối?',
#   'Thông thường bạn thức dậy vào lúc mấy giờ sáng?',
#   'Thông thường bạn mất khoảng bao lâu để đi vào giấc ngủ đêm?',
#   'Thông thường giấc ngủ trưa của bạn kéo dài bao lâu?',
#   'Trung bình mỗi ngày bạn ngủ bao nhiêu giờ trong một ngày (24 giờ)?',
#   'Bạn đánh giá chất lượng giấc ngủ chung của mình như thế nào?',
#   'Giấc ngủ của bạn có hay bị gián đoạn (vd: thức giấc nửa đêm, ngủ không yên) khong?',
#   'Bạn có sử dụng bất kỳ loại thuốc nào để hỗ trợ giấc ngủ không?',
#   'Địa chỉ email của bạn']}

# %% [markdown]
# Let's drop Username and Email columns for privacy

# %%
for lang, df in dfs.items():
    try:
        # Email column is the last column
        df.drop(labels=df.columns[-1], axis=1, inplace=True)

        # Drop username column if present
        df.drop(columns='Username', inplace=True)
    except Exception as err:
        pass
        # print(err)

# %% [markdown]
# ## Bengali

# %% [markdown]
# ### Translate Headers to English

# %%
dfs['Bengali'].head(3)
# Out:
#                      Timestamp আপনার বয়স কত?* আপনার লিঙ্গ কি? *  \
# 0  2023/11/07 3:26:01 PM GMT+9           ২৫-৩৪             মহিলা
# 1  2023/11/07 3:45:02 PM GMT+9           ২৫-৩৪             মহিলা
# 2  2023/11/07 3:51:38 PM GMT+9           ২৫-৩৪             মহিলা
#
#   আপনার শিক্ষাগত যোগ্যতা কি? *\n আপনার পেশা কি? *  \
# 0               মাস্টার্স ডিগ্রি        অন্যান্য:
# 1               মাস্টার্স ডিগ্রি        অন্যান্য:
# 2                ব্যাচলার ডিগ্রি        অন্যান্য:
#
#   গড়ে সপ্তাহে কয়দিন আপনি কমপক্ষে ৩০ মিনিট বা তার চেয়ে বেশি সময়ের জন্য ব্যায়াম করেন? *  \
# 0                                            ১-২ দিন
# 1                                            ৩-৪ দিন
# 2                                              ০ দিন
#
#   গড়ে আপনি কত ঘণ্টা ইলেকট্রনিক ডিভাইস ব্যবহার করেন, যেমন স্মার্টফোন, ল্যাপটপ, টেলিভিশন, ইত্যাদি?   \
# 0                                          ১-৩ ঘণ্টা
# 1                                          ৪-৬ ঘণ্টা
# 2                                   ৭ অথবা আরও ঘণ্টা
#
#   গড়ে আপনি ঘুমানোর আগে ফোনে / ল্যপটপে কতটুকু সময় অতিবাহিত করেন?  \
# 0                                 ৩০ মিনিট - ১ ঘণ্টা
# 1                                      ৩০ মিনিটের কম
# 2                              ২ ঘণ্টা অথবা তার বেশি
#
#    (ঐচ্ছিক) আপনার উচ্চতা কত? (সে.মি. এককে)  (ঐচ্ছিক) আপনার ওজন কত? (কেজি তে)  \
# 0                                    152.4                              47.0
# 1                                      NaN                               NaN
# 2                                    153.4                              68.0
#
#   রাতে সাধারনত কখন ঘুমাতে যান? সাধারনত আপনি সকালে কখন ঘুম থেকে উঠেন?  \
# 0                        23:00                                 06:30
# 1                        00:00                                 08:30
# 2                        00:30                                 09:30
#
#   সাধারনত শোয়ার কতক্ষনের মধ্যে আপনার ঘুম চলে আসে?  \
# 0                                 ৬০ মিনিটের বেশি
# 1                                     ১৫-৩০ মিনিট
# 2                                   ১৫ মিনিটের কম
#
#   আপনি কি দিনের বেলা সামান্য ঘুমিয়ে নেন? যদি উত্তর হ্যা হয়, তাহলে তা কতক্ষন?  \
# 0                               হ্যাঁ, ৩০ মিনিটের কম
# 1                               হ্যাঁ, ৩০ মিনিটের কম
# 2                              না, আমি দিনে ঘুমায় না
#
#   সব মিলিয়ে গড়ে আপনি ২৪ ঘণ্টার মধ্যে কত ঘণ্টা ঘুমান?  \
# 0                                          ৪-৬ ঘণ্টা
# 1                               ৬ ঘণ্টা এবং তার বেশি
# 2                                          ৪-৬ ঘণ্টা
#
#    আপনার সামগ্রীক ঘুমের মান কেমন থাকে?   \
# 0                                     2
# 1                                     4
# 2                                     3
#
#   আপনি কি পরিমান ঘুমের মধ্য বিঘ্নতা পরিলক্ষন করেন, যেমন রাতে ঘুম ভেঙ্গে যাওয়া বা খুব হালকা ঘুম?  \
# 0                                         প্রায় সময়ই
# 1                                        মাঝে মধ্যেই
# 2                                         প্রায় সময়ই
#
#   আপনি কি ঘুমের জন্য কোন ঔষধ সেবন করেন?
# 0                                    না
# 1                                    না
# 2                                    না

# %% [markdown]
# Column Headers are too lengthy and hard to read. Let's rename them to English

# %%
# Define the new column names
new_column_names = {
    'Timestamp': 'Timestamp',
    # 'Username': 'User ID',
    'আপনার বয়স কত?*': 'Age Group',
    'আপনার লিঙ্গ কি? *': 'Gender',
    'আপনার শিক্ষাগত যোগ্যতা কি? *\n': 'Education Level',
    'আপনার পেশা কি? *': 'Occupation',
    'গড়ে সপ্তাহে কয়দিন আপনি কমপক্ষে ৩০ মিনিট বা তার চেয়ে বেশি সময়ের জন্য ব্যায়াম করেন? *': 'Exercise Days/Week',
    'গড়ে আপনি কত ঘণ্টা ইলেকট্রনিক ডিভাইস ব্যবহার করেন, যেমন স্মার্টফোন, ল্যাপটপ, টেলিভিশন, ইত্যাদি? ': 'Device Usage (hrs/day)',
    'গড়ে আপনি ঘুমানোর আগে ফোনে / ল্যপটপে কতটুকু সময় অতিবাহিত করেন?': 'Screen Time Before Sleep',
    '(ঐচ্ছিক) আপনার উচ্চতা কত? (সে.মি. এককে)': 'Height (cm)',
    '(ঐচ্ছিক) আপনার ওজন কত? (কেজি তে)': 'Weight (kg)',
    'রাতে সাধারনত কখন ঘুমাতে যান?': 'Bedtime',
    'সাধারনত আপনি সকালে কখন ঘুম থেকে উঠেন?': 'Wake-up Time',
    'সাধারনত শোয়ার কতক্ষনের মধ্যে আপনার ঘুম চলে আসে?': 'Sleep Onset Time',
    'আপনি কি দিনের বেলা সামান্য ঘুমিয়ে নেন? যদি উত্তর হ্যা হয়, তাহলে তা কতক্ষন?': 'Nap Duration',
    'সব মিলিয়ে গড়ে আপনি ২৪ ঘণ্টার মধ্যে কত ঘণ্টা ঘুমান?': 'Sleep Duration (hrs/24hr)',
    'আপনার সামগ্রীক ঘুমের মান কেমন থাকে? ': 'Sleep Quality',
    'আপনি কি পরিমান ঘুমের মধ্য বিঘ্নতা পরিলক্ষন করেন, যেমন রাতে ঘুম ভেঙ্গে যাওয়া বা খুব হালকা ঘুম?': 'Sleep Disturbances',
    'আপনি কি ঘুমের জন্য কোন ঔষধ সেবন করেন?': 'Sleep Medication',
    'আপনার ইমেল ঠিকানা': 'Email Address'
}

# Rename the columns
dfs['Bengali'].rename(columns=new_column_names, inplace=True)

# Show the updated DataFrame
dfs['Bengali'].head()
# Out:
#                      Timestamp Age Group Gender            Education Level  \
# 0  2023/11/07 3:26:01 PM GMT+9     ২৫-৩৪  মহিলা           মাস্টার্স ডিগ্রি
# 1  2023/11/07 3:45:02 PM GMT+9     ২৫-৩৪  মহিলা           মাস্টার্স ডিগ্রি
# 2  2023/11/07 3:51:38 PM GMT+9     ২৫-৩৪  মহিলা            ব্যাচলার ডিগ্রি
# 3  2023/11/07 3:53:05 PM GMT+9     ২৫-৩৪  মহিলা  ডক্টরেট বা পেশাদার ডিগ্রি
# 4  2023/11/07 4:05:44 PM GMT+9     ২৫-৩৪  পুরুষ           মাস্টার্স ডিগ্রি
#
#              Occupation Exercise Days/Week Device Usage (hrs/day)  \
# 0             অন্যান্য:            ১-২ দিন              ১-৩ ঘণ্টা
# 1             অন্যান্য:            ৩-৪ দিন              ৪-৬ ঘণ্টা
# 2             অন্যান্য:              ০ দিন       ৭ অথবা আরও ঘণ্টা
# 3  পেশাদার / অফিস কর্মী      ৫ বা আরও বেশি       ৭ অথবা আরও ঘণ্টা
# 4                 ছাত্র      ৫ বা আরও বেশি              ১-৩ ঘণ্টা
#
#   Screen Time Before Sleep  Height (cm)  Weight (kg) Bedtime Wake-up Time  \
# 0       ৩০ মিনিট - ১ ঘণ্টা        152.4         47.0   23:00        06:30
# 1            ৩০ মিনিটের কম          NaN          NaN   00:00        08:30
# 2    ২ ঘণ্টা অথবা তার বেশি        153.4         68.0   00:30        09:30
# 3       ৩০ মিনিট - ১ ঘণ্টা        154.0         59.2   22:50        06:20
# 4            ৩০ মিনিটের কম        171.0         75.0   22:00        06:00
#
#   Sleep Onset Time           Nap Duration Sleep Duration (hrs/24hr)  \
# 0  ৬০ মিনিটের বেশি   হ্যাঁ, ৩০ মিনিটের কম                 ৪-৬ ঘণ্টা
# 1      ১৫-৩০ মিনিট   হ্যাঁ, ৩০ মিনিটের কম      ৬ ঘণ্টা এবং তার বেশি
# 2    ১৫ মিনিটের কম  না, আমি দিনে ঘুমায় না                 ৪-৬ ঘণ্টা
# 3      ১৫-৩০ মিনিট  না, আমি দিনে ঘুমায় না      ৬ ঘণ্টা এবং তার বেশি
# 4      ১৫-৩০ মিনিট  না, আমি দিনে ঘুমায় না      ৬ ঘণ্টা এবং তার বেশি
#
#    Sleep Quality Sleep Disturbances Sleep Medication
# 0              2         প্রায় সময়ই               না
# 1              4        মাঝে মধ্যেই               না
# 2              3         প্রায় সময়ই               না
# 3              3          হঠাৎ হঠাৎ               না
# 4              4          হঠাৎ হঠাৎ               না

# %% [markdown]
# ### Translate Cell values to English

# %%
dfs['Bengali']['Education Level'].unique()
# Out:
# array(['মাস্টার্স ডিগ্রি', 'ব্যাচলার ডিগ্রি', 'ডক্টরেট বা পেশাদার ডিগ্রি',
#        'উচ্চ মাধ্যমিক'], dtype=object)

# %%
gender_mapping = {
    'পুরুষ': 'Male',
    'মহিলা': 'Female',
    'অন্যান্য': 'Other',
    # Add more mappings as needed
}

education_mapping = {
    'মাস্টার্স ডিগ্রি': "Master's Degree",
    'ব্যাচলার ডিগ্রি': "Bachelor's Degree",
    'ডক্টরেট বা পেশাদার ডিগ্রি': 'Doctorate or Professional Degree',
    'উচ্চ মাধ্যমিক': 'Higher Secondary'
}

dfs['Bengali']['Gender'] = dfs['Bengali']['Gender'].map(gender_mapping)
dfs['Bengali']['Education Level'] = dfs['Bengali']['Education Level'].map(education_mapping)
dfs['Bengali'].sample(3)
# Out:
#                        Timestamp Age Group  Gender  \
# 10   2023/11/07 5:52:10 PM GMT+9     ২৫-৩৪  Female
# 19   2023/11/07 8:31:58 PM GMT+9     ২৫-৩৪    Male
# 21  2023/11/07 11:29:19 PM GMT+9     ২৫-৩৪    Male
#
#                      Education Level            Occupation Exercise Days/Week  \
# 10                   Master's Degree             অন্যান্য:              ০ দিন
# 19  Doctorate or Professional Degree                 ছাত্র            ১-২ দিন
# 21                   Master's Degree  পেশাদার / অফিস কর্মী      ৫ বা আরও বেশি
#
#    Device Usage (hrs/day) Screen Time Before Sleep  Height (cm)  Weight (kg)  \
# 10              ১-৩ ঘণ্টা            ৩০ মিনিটের কম          NaN          NaN
# 19              ৪-৬ ঘণ্টা                ১-২ ঘণ্টা       171.00         75.0
# 21              ৪-৬ ঘণ্টা    ২ ঘণ্টা অথবা তার বেশি        14.22         56.0
#
#    Bedtime Wake-up Time Sleep Onset Time          Nap Duration  \
# 10   11:00        08:30      ১৫-৩০ মিনিট  হ্যাঁ, ৩০ মিনিটের কম
# 19   01:00        09:30      ১৫-৩০ মিনিট    হ্যাঁ, ৩০-৬০ মিনিট
# 21   01:00        07:00      ৩০-৬০ মিনিট    হ্যাঁ, ৩০-৬০ মিনিট
#
#    Sleep Duration (hrs/24hr)  Sleep Quality Sleep Disturbances  \
# 10                 ৪-৬ ঘণ্টা              4        মাঝে মধ্যেই
# 19      ৬ ঘণ্টা এবং তার বেশি              3          হঠাৎ হঠাৎ
# 21                 ৪-৬ ঘণ্টা              3        মাঝে মধ্যেই
#
#    Sleep Medication
# 10               না
# 19               না
# 21               না
