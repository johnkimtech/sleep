# %%
# Make Jupyter reload library before every execution

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Translation

# %% [markdown]
# Each data file is in a different language. We need to translate them into English before concatenation.
# First, we'll examine the headers

# %%
# We code some function for preprocessing here
import utils

# %%
import pandas as pd

# Load the survey data files
file_paths = {
    'English': 'data/en.csv',
    'Bengali': 'data/bengali.csv',
    'Korean': 'data/kr.csv',
    'Vietnamese': 'data/vi.csv'
}

# Read the headers of each file
dfs = {}
headers = {}
for language, file_path in file_paths.items():
    df = pd.read_csv(file_path, parse_dates=True)  # Read only headers
    dfs[language] = df
    headers[language] = df.columns.tolist()

headers
# Out:
# {'English': ['Timestamp',
#   'What is your age group?',
#   'What is your gender?',
#   'What is the highest level of education you have completed?',
#   'Which category best describes your occupation?',
#   'On average, how many days per week do you exercise for at least 30 (or under 30 mins but high intensity) minutes? ',
#   'On average, how many hours per day do you use electronic devices such as smartphones, laptops, televisions, etc.? ',
#   'On average, how much time do you usually spend on phone / computers before sleep?',
#   '(Optional) What is your height in centimeters?',
#   '(Optional) What is your weight in kilograms?',
#   'On average, what time do you typically go to bed at night?',
#   'On average, what time do you typically wake up in the morning?',
#   'On average, how long does it take you to fall asleep at night?',
#   'On average, how long is your typical daytime nap?',
#   'On average, how many hours do you sleep per 24-hour period?',
#   'How would you rate your overall sleep quality?',
#   'How often do you experience sleep disturbances such as waking up during the night or having restless sleep?',
#   'Do you take any medication to help you sleep?',
#   'Your email address'],
#  'Bengali': ['Timestamp',
#   'Username',
#   'আপনার বয়স কত?*',
#   'আপনার লিঙ্গ কি? *',
#   'আপনার শিক্ষাগত যোগ্যতা কি? *\n',
#   'আপনার পেশা কি? *',
#   'গড়ে সপ্তাহে কয়দিন আপনি কমপক্ষে ৩০ মিনিট বা তার চেয়ে বেশি সময়ের জন্য ব্যায়াম করেন? *',
#   'গড়ে আপনি কত ঘণ্টা ইলেকট্রনিক ডিভাইস ব্যবহার করেন, যেমন স্মার্টফোন, ল্যাপটপ, টেলিভিশন, ইত্যাদি? ',
#   'গড়ে আপনি ঘুমানোর আগে ফোনে / ল্যপটপে কতটুকু সময় অতিবাহিত করেন?',
#   '(ঐচ্ছিক) আপনার উচ্চতা কত? (সে.মি. এককে)',
#   '(ঐচ্ছিক) আপনার ওজন কত? (কেজি তে)',
#   'রাতে সাধারনত কখন ঘুমাতে যান?',
#   'সাধারনত আপনি সকালে কখন ঘুম থেকে উঠেন?',
#   'সাধারনত শোয়ার কতক্ষনের মধ্যে আপনার ঘুম চলে আসে?',
#   'আপনি কি দিনের বেলা সামান্য ঘুমিয়ে নেন? যদি উত্তর হ্যা হয়, তাহলে তা কতক্ষন?',
#   'সব মিলিয়ে গড়ে আপনি ২৪ ঘণ্টার মধ্যে কত ঘণ্টা ঘুমান?',
#   'আপনার সামগ্রীক ঘুমের মান কেমন থাকে? ',
#   'আপনি কি পরিমান ঘুমের মধ্য বিঘ্নতা পরিলক্ষন করেন, যেমন রাতে ঘুম ভেঙ্গে যাওয়া বা খুব হালকা ঘুম?',
#   'আপনি কি ঘুমের জন্য কোন ঔষধ সেবন করেন?',
#   'আপনার ইমেল ঠিকানা'],
#  'Korean': ['Timestamp',
#   '귀하의 나이는 어떻게 되십니까?',
#   '귀하의 성별은 무엇입니까?',
#   '귀하의 최종 학력은 무엇입니까?',
#   '귀하의 직업은 무엇입니까?',
#   '일주일에 평균 며칠 동안 적어도 30분 이상 운동을 하십니까?',
#   '하루 평균 스마트폰, 노트북, TV 등 전자기기를 사용하는 시간이 얼마나 됩니까?',
#   '자기 전 전화/컴퓨터를 보는 시간이 일반적으로 얼마나 됩니까?',
#   '(선택 사항) 키는 센티미터로 몇이에요?',
#   '(선택 사항) 몸무게는 킬로그램으로 몇이에요?',
#   '보통 밤 몇 시에 잠자리에 드십니까?',
#   '보통 아침 몇 시에 일어나십니까? ',
#   '보통 밤에 잠든 후 대략 얼마나 걸리십니까?',
#   '일반적으로 낮잠 시간이 얼마나 됩니까?',
#   '24시간 기준 일일 평균 수면 시간이 얼마나 됩니까?',
#   '전체적인 수면 질을 어떻게 평가하십니까?',
#   '아침에 자주 깨는 등 수면 장애 증상이 얼마나 자주 있습니까?',
#   '수면 약을 복용하십니까?',
#   '귀하의 이메일 주소'],
#  'Vietnamese': ['Timestamp',
#   'Bạn bao nhiêu tuổi?',
#   'Giới tính của bạn? ',
#   'Trình độ học vấn cao nhất của bạn? ',
#   'Nghề nghiệp của bạn?',
#   'Trung bình mỗi tuần bạn tập thể dục ít nhất 30 phút (hoặc dưới 30p nhưng cường độ cao) bao nhiêu ngày?',
#   'Trung bình mỗi ngày bạn dùng các thiết bị điện tử như điện thoại thông minh, máy tính xách tay, ti vi, v.v. bao nhiêu giờ?',
#   'Trung bình bạn dành bao nhiêu thời gian sử dụng điện thoại/máy tính trước khi đi ngủ? ',
#   '(Không bắt buộc) Chiều cao của bạn là bao nhiêu cm?',
#   '(Không bắt buộc) Cân nặng của bạn là bao nhiêu kg?',
#   'Thông thường bạn đi ngủ vào lúc mấy giờ tối?',
#   'Thông thường bạn thức dậy vào lúc mấy giờ sáng?',
#   'Thông thường bạn mất khoảng bao lâu để đi vào giấc ngủ đêm?',
#   'Thông thường giấc ngủ trưa của bạn kéo dài bao lâu?',
#   'Trung bình mỗi ngày bạn ngủ bao nhiêu giờ trong một ngày (24 giờ)?',
#   'Bạn đánh giá chất lượng giấc ngủ chung của mình như thế nào?',
#   'Giấc ngủ của bạn có hay bị gián đoạn (vd: thức giấc nửa đêm, ngủ không yên) khong?',
#   'Bạn có sử dụng bất kỳ loại thuốc nào để hỗ trợ giấc ngủ không?',
#   'Địa chỉ email của bạn']}

# %% [markdown]
# Let's drop Username and Email columns for privacy

# %%
for lang, df in dfs.items():
    try:
        # Email column is the last column
        df.drop(labels=df.columns[-1], axis=1, inplace=True)

        # Drop username column if present
        df.drop(columns='Username', inplace=True)
    except Exception as err:
        pass
        # print(err)

# %% [markdown]
# As you can see, column headers are lengthy, which could make it harder for us to analyze. In the next section, we will translate and shorten them while trying to maintaining the original meaning as close as possible.

# %% [markdown]
# ## Bengali

# %% [markdown]
# ### Translate Headers to English

# %%
dfs['Bengali'].head(3)
# Out:
#                      Timestamp আপনার বয়স কত?* আপনার লিঙ্গ কি? *  \
# 0  2023/11/07 3:26:01 PM GMT+9           ২৫-৩৪             মহিলা
# 1  2023/11/07 3:45:02 PM GMT+9           ২৫-৩৪             মহিলা
# 2  2023/11/07 3:51:38 PM GMT+9           ২৫-৩৪             মহিলা
#
#   আপনার শিক্ষাগত যোগ্যতা কি? *\n আপনার পেশা কি? *  \
# 0               মাস্টার্স ডিগ্রি        অন্যান্য:
# 1               মাস্টার্স ডিগ্রি        অন্যান্য:
# 2                ব্যাচলার ডিগ্রি        অন্যান্য:
#
#   গড়ে সপ্তাহে কয়দিন আপনি কমপক্ষে ৩০ মিনিট বা তার চেয়ে বেশি সময়ের জন্য ব্যায়াম করেন? *  \
# 0                                            ১-২ দিন
# 1                                            ৩-৪ দিন
# 2                                              ০ দিন
#
#   গড়ে আপনি কত ঘণ্টা ইলেকট্রনিক ডিভাইস ব্যবহার করেন, যেমন স্মার্টফোন, ল্যাপটপ, টেলিভিশন, ইত্যাদি?   \
# 0                                          ১-৩ ঘণ্টা
# 1                                          ৪-৬ ঘণ্টা
# 2                                   ৭ অথবা আরও ঘণ্টা
#
#   গড়ে আপনি ঘুমানোর আগে ফোনে / ল্যপটপে কতটুকু সময় অতিবাহিত করেন?  \
# 0                                 ৩০ মিনিট - ১ ঘণ্টা
# 1                                      ৩০ মিনিটের কম
# 2                              ২ ঘণ্টা অথবা তার বেশি
#
#    (ঐচ্ছিক) আপনার উচ্চতা কত? (সে.মি. এককে)  (ঐচ্ছিক) আপনার ওজন কত? (কেজি তে)  \
# 0                                    152.4                              47.0
# 1                                      NaN                               NaN
# 2                                    153.4                              68.0
#
#   রাতে সাধারনত কখন ঘুমাতে যান? সাধারনত আপনি সকালে কখন ঘুম থেকে উঠেন?  \
# 0                        23:00                                 06:30
# 1                        00:00                                 08:30
# 2                        00:30                                 09:30
#
#   সাধারনত শোয়ার কতক্ষনের মধ্যে আপনার ঘুম চলে আসে?  \
# 0                                 ৬০ মিনিটের বেশি
# 1                                     ১৫-৩০ মিনিট
# 2                                   ১৫ মিনিটের কম
#
#   আপনি কি দিনের বেলা সামান্য ঘুমিয়ে নেন? যদি উত্তর হ্যা হয়, তাহলে তা কতক্ষন?  \
# 0                               হ্যাঁ, ৩০ মিনিটের কম
# 1                               হ্যাঁ, ৩০ মিনিটের কম
# 2                              না, আমি দিনে ঘুমায় না
#
#   সব মিলিয়ে গড়ে আপনি ২৪ ঘণ্টার মধ্যে কত ঘণ্টা ঘুমান?  \
# 0                                          ৪-৬ ঘণ্টা
# 1                               ৬ ঘণ্টা এবং তার বেশি
# 2                                          ৪-৬ ঘণ্টা
#
#    আপনার সামগ্রীক ঘুমের মান কেমন থাকে?   \
# 0                                     2
# 1                                     4
# 2                                     3
#
#   আপনি কি পরিমান ঘুমের মধ্য বিঘ্নতা পরিলক্ষন করেন, যেমন রাতে ঘুম ভেঙ্গে যাওয়া বা খুব হালকা ঘুম?  \
# 0                                         প্রায় সময়ই
# 1                                        মাঝে মধ্যেই
# 2                                         প্রায় সময়ই
#
#   আপনি কি ঘুমের জন্য কোন ঔষধ সেবন করেন?
# 0                                    না
# 1                                    না
# 2                                    না

# %% [markdown]
# Column Headers are too lengthy and hard to read. Let's rename them to English

# %%
# Define the new column names
new_column_names = {
    'Timestamp': 'Timestamp',
    'আপনার বয়স কত?*': 'Age Group',
    'আপনার লিঙ্গ কি? *': 'Gender',
    'আপনার শিক্ষাগত যোগ্যতা কি? *\n': 'Education Level',
    'আপনার পেশা কি? *': 'Occupation',
    'গড়ে সপ্তাহে কয়দিন আপনি কমপক্ষে ৩০ মিনিট বা তার চেয়ে বেশি সময়ের জন্য ব্যায়াম করেন? *': 'Exercise Days/Week',
    'গড়ে আপনি কত ঘণ্টা ইলেকট্রনিক ডিভাইস ব্যবহার করেন, যেমন স্মার্টফোন, ল্যাপটপ, টেলিভিশন, ইত্যাদি? ': 'Device Usage (hrs/day)',
    'গড়ে আপনি ঘুমানোর আগে ফোনে / ল্যপটপে কতটুকু সময় অতিবাহিত করেন?': 'Screen Time Before Sleep',
    '(ঐচ্ছিক) আপনার উচ্চতা কত? (সে.মি. এককে)': 'Height (cm)',
    '(ঐচ্ছিক) আপনার ওজন কত? (কেজি তে)': 'Weight (kg)',
    'রাতে সাধারনত কখন ঘুমাতে যান?': 'Bedtime',
    'সাধারনত আপনি সকালে কখন ঘুম থেকে উঠেন?': 'Wake-up Time',
    'সাধারনত শোয়ার কতক্ষনের মধ্যে আপনার ঘুম চলে আসে?': 'Sleep Onset Time',
    'আপনি কি দিনের বেলা সামান্য ঘুমিয়ে নেন? যদি উত্তর হ্যা হয়, তাহলে তা কতক্ষন?': 'Nap Duration',
    'সব মিলিয়ে গড়ে আপনি ২৪ ঘণ্টার মধ্যে কত ঘণ্টা ঘুমান?': 'Sleep Duration (hrs/24hr)',
    'আপনার সামগ্রীক ঘুমের মান কেমন থাকে? ': 'Sleep Quality',
    'আপনি কি পরিমান ঘুমের মধ্য বিঘ্নতা পরিলক্ষন করেন, যেমন রাতে ঘুম ভেঙ্গে যাওয়া বা খুব হালকা ঘুম?': 'Sleep Disturbances',
    'আপনি কি ঘুমের জন্য কোন ঔষধ সেবন করেন?': 'Sleep Medication',
}

# Rename the columns
dfs['Bengali'].rename(columns=new_column_names, inplace=True)

# Show the updated DataFrame
dfs['Bengali'].head()
# Out:
#                      Timestamp Age Group Gender            Education Level  \
# 0  2023/11/07 3:26:01 PM GMT+9     ২৫-৩৪  মহিলা           মাস্টার্স ডিগ্রি
# 1  2023/11/07 3:45:02 PM GMT+9     ২৫-৩৪  মহিলা           মাস্টার্স ডিগ্রি
# 2  2023/11/07 3:51:38 PM GMT+9     ২৫-৩৪  মহিলা            ব্যাচলার ডিগ্রি
# 3  2023/11/07 3:53:05 PM GMT+9     ২৫-৩৪  মহিলা  ডক্টরেট বা পেশাদার ডিগ্রি
# 4  2023/11/07 4:05:44 PM GMT+9     ২৫-৩৪  পুরুষ           মাস্টার্স ডিগ্রি
#
#              Occupation Exercise Days/Week Device Usage (hrs/day)  \
# 0             অন্যান্য:            ১-২ দিন              ১-৩ ঘণ্টা
# 1             অন্যান্য:            ৩-৪ দিন              ৪-৬ ঘণ্টা
# 2             অন্যান্য:              ০ দিন       ৭ অথবা আরও ঘণ্টা
# 3  পেশাদার / অফিস কর্মী      ৫ বা আরও বেশি       ৭ অথবা আরও ঘণ্টা
# 4                 ছাত্র      ৫ বা আরও বেশি              ১-৩ ঘণ্টা
#
#   Screen Time Before Sleep  Height (cm)  Weight (kg) Bedtime Wake-up Time  \
# 0       ৩০ মিনিট - ১ ঘণ্টা        152.4         47.0   23:00        06:30
# 1            ৩০ মিনিটের কম          NaN          NaN   00:00        08:30
# 2    ২ ঘণ্টা অথবা তার বেশি        153.4         68.0   00:30        09:30
# 3       ৩০ মিনিট - ১ ঘণ্টা        154.0         59.2   22:50        06:20
# 4            ৩০ মিনিটের কম        171.0         75.0   22:00        06:00
#
#   Sleep Onset Time           Nap Duration Sleep Duration (hrs/24hr)  \
# 0  ৬০ মিনিটের বেশি   হ্যাঁ, ৩০ মিনিটের কম                 ৪-৬ ঘণ্টা
# 1      ১৫-৩০ মিনিট   হ্যাঁ, ৩০ মিনিটের কম      ৬ ঘণ্টা এবং তার বেশি
# 2    ১৫ মিনিটের কম  না, আমি দিনে ঘুমায় না                 ৪-৬ ঘণ্টা
# 3      ১৫-৩০ মিনিট  না, আমি দিনে ঘুমায় না      ৬ ঘণ্টা এবং তার বেশি
# 4      ১৫-৩০ মিনিট  না, আমি দিনে ঘুমায় না      ৬ ঘণ্টা এবং তার বেশি
#
#    Sleep Quality Sleep Disturbances Sleep Medication
# 0              2         প্রায় সময়ই               না
# 1              4        মাঝে মধ্যেই               না
# 2              3         প্রায় সময়ই               না
# 3              3          হঠাৎ হঠাৎ               না
# 4              4          হঠাৎ হঠাৎ               না

# %% [markdown]
# ### Translate Cell values to English

# %%
bengali_translation_dict = {
    "Gender": {"পুরুষ": "Male", "মহিলা": "Female", "অন্যান্য": "Other"},
    "Age Group": {
        "১৬-২৪": "16-24",
        "২৫-৩৪": "25-34",
        "৩৫-৪৪": "35-44",
        "৪৫-৫৪": "45-54",
        "৫৫+": "55+",
        "অন্যান্য": "Other",
    },
    "Education Level": {
        "মাস্টার্স ডিগ্রি": "Master's",
        "ব্যাচলার ডিগ্রি": "Bachelor's",
        "ডক্টরেট বা পেশাদার ডিগ্রি": "Doctorate/Prof.",
        "উচ্চ মাধ্যমিক": "High School",
    },
    "Occupation": {
        "অন্যান্য:": "Other",
        "পেশাদার / অফিস কর্মী": "Professional/Office Worker",
        "ছাত্র": "Student",
        "বেকার": "Unemployed",
        "পরিষেবা (বিক্রয়, খাদ্য পরিষেবা ইত্যাদি)": "Service",
    },
    "Exercise Days/Week": {
        "১-২ দিন": "1-2 Days",
        "৩-৪ দিন": "3-4 Days",
        "০ দিন": "0 Days",
        "৫ বা আরও বেশি": "5+ Days",
    },
    "Device Usage (hrs/day)": {
        "১-৩ ঘণ্টা": "1-3 Hours",
        "৪-৬ ঘণ্টা": "4-6 Hours",
        "৭ অথবা আরও ঘণ্টা": "7+ Hours",
    },
    "Screen Time Before Sleep": {
        "৩০ মিনিট - ১ ঘণ্টা": "30-60 Minutes",
        "৩০ মিনিটের কম": "<30 Minutes",
        "২ ঘণ্টা অথবা তার বেশি": "2+ Hours",
        "১-২ ঘণ্টা": "1-2 Hours",
    },
    "Sleep Onset Time": {
        "৬০ মিনিটের বেশি": ">60 Minutes",
        "১৫-৩০ মিনিট": "15-30 Minutes",
        "১৫ মিনিটের কম": "<15 Minutes",
        "৩০-৬০ মিনিট": "30-60 Minutes",
    },
    "Nap Duration": {
        "হ্যাঁ, ৩০ মিনিটের কম": "Yes, <30 mins",
        "না, আমি দিনে ঘুমায় না": "No Nap",
        "হ্যাঁ, ৩০-৬০ মিনিট": "Yes, 30-60 mins",
        "হ্যাঁ, ৯০ মিনিটের বেশি": "Yes, >90 mins",
    },
    "Sleep Duration (hrs/24hr)": {
        "৪-৬ ঘণ্টা": "4-6 Hours",
        "৬ ঘণ্টা এবং তার বেশি": "6+ Hours",
    },
    "Sleep Disturbances": {
        "প্রায় সময়ই": "Often",
        "মাঝে মধ্যেই": "Sometimes",
        "হঠাৎ হঠাৎ": "Rarely",
        "কখনও না": "Never",
    },
    "Sleep Medication": {"না": "No", "হ্যাঁ": "Yes"},
}


utils.translate_cells(dfs["Bengali"], bengali_translation_dict)
dfs["Bengali"]["Language"] = "Bengali"
dfs["Bengali"].sample(5)
# Out:
#                        Timestamp Age Group Gender  Education Level Occupation  \
# 15   2023/11/07 6:30:06 PM GMT+9     Other   Male  Doctorate/Prof.      Other
# 7    2023/11/07 5:11:03 PM GMT+9     25-34   Male         Master's      Other
# 20  2023/11/07 10:35:48 PM GMT+9     25-34   Male         Master's    Student
# 13   2023/11/07 6:21:11 PM GMT+9     25-34   Male  Doctorate/Prof.    Student
# 16   2023/11/07 6:32:06 PM GMT+9     25-34   Male         Master's    Student
#
#    Exercise Days/Week Device Usage (hrs/day) Screen Time Before Sleep  \
# 15           1-2 Days               7+ Hours            30-60 Minutes
# 7            3-4 Days              4-6 Hours              <30 Minutes
# 20           3-4 Days              4-6 Hours            30-60 Minutes
# 13           3-4 Days              1-3 Hours            30-60 Minutes
# 16            5+ Days              4-6 Hours            30-60 Minutes
#
#     Height (cm)  Weight (kg) Bedtime Wake-up Time Sleep Onset Time  \
# 15          NaN          NaN   00:00        08:00    15-30 Minutes
# 7           NaN          NaN   23:00        07:00      <15 Minutes
# 20         65.0         68.0   23:00        07:00    15-30 Minutes
# 13         72.0         78.0   13:00        09:00    30-60 Minutes
# 16          NaN          NaN   22:00        05:30    15-30 Minutes
#
#      Nap Duration Sleep Duration (hrs/24hr)  Sleep Quality Sleep Disturbances  \
# 15         No Nap                  6+ Hours              3              Never
# 7   Yes, <30 mins                  6+ Hours              4          Sometimes
# 20         No Nap                  6+ Hours              4             Rarely
# 13         No Nap                  6+ Hours              2             Rarely
# 16         No Nap                  6+ Hours              4             Rarely
#
#    Sleep Medication Language
# 15               No  Bengali
# 7                No  Bengali
# 20               No  Bengali
# 13              Yes  Bengali
# 16               No  Bengali

# %% [markdown]
# Now, the Bengali survey data is completely translated. Now, we'll do the same thing other the remaining languages.

# %% [markdown]
# ## Vietnamese

# %% [markdown]
# ### Before

# %%
dfs['Vietnamese'].sample(5)
# Out:
#                        Timestamp Bạn bao nhiêu tuổi? Giới tính của bạn?   \
# 3   2023/11/07 11:58:10 AM GMT+9               16-24                 Nam
# 7    2023/11/07 1:28:45 PM GMT+9               25-34                  Nữ
# 15   2023/11/08 9:06:41 AM GMT+9               25-34                  Nữ
# 13   2023/11/07 7:08:39 PM GMT+9               25-34                  Nữ
# 10   2023/11/07 4:45:50 PM GMT+9               25-34                  Nữ
#
#    Trình độ học vấn cao nhất của bạn?      Nghề nghiệp của bạn?  \
# 3                                 THPT     Học sinh / Sinh viên
# 7                              Tiến sĩ     Học sinh / Sinh viên
# 15                             Tiến sĩ                Reseacher
# 13                             Cử nhân     Học sinh / Sinh viên
# 10                             Tiến sĩ  Chuyên nghiệp/văn phòng
#
#    Trung bình mỗi tuần bạn tập thể dục ít nhất 30 phút (hoặc dưới 30p nhưng cường độ cao) bao nhiêu ngày?  \
# 3                                              0 ngày
# 7                                      5 ngày trở lên
# 15                                             0 ngày
# 13                                           1-2 ngày
# 10                                           1-2 ngày
#
#    Trung bình mỗi ngày bạn dùng các thiết bị điện tử như điện thoại thông minh, máy tính xách tay, ti vi, v.v. bao nhiêu giờ?  \
# 3                                       7 giờ trở lên
# 7                                       7 giờ trở lên
# 15                                            4-6 giờ
# 13                                            4-6 giờ
# 10                                            4-6 giờ
#
#    Trung bình bạn dành bao nhiêu thời gian sử dụng điện thoại/máy tính trước khi đi ngủ?   \
# 3                                      Ít hơn 30 phút
# 7                                             1-2 giờ
# 15                                    30 phút - 1 giờ
# 13                                            1-2 giờ
# 10                                            1-2 giờ
#
#     (Không bắt buộc) Chiều cao của bạn là bao nhiêu cm?  \
# 3                                               175.0
# 7                                               160.0
# 15                                              154.0
# 13                                              155.0
# 10                                              152.0
#
#     (Không bắt buộc) Cân nặng của bạn là bao nhiêu kg?  \
# 3                                                85.0
# 7                                                60.0
# 15                                               44.0
# 13                                               44.0
# 10                                                NaN
#
#    Thông thường bạn đi ngủ vào lúc mấy giờ tối?  \
# 3                                         23:30
# 7                                         02:00
# 15                                        01:00
# 13                                        12:00
# 10                                        00:00
#
#    Thông thường bạn thức dậy vào lúc mấy giờ sáng?  \
# 3                                            05:30
# 7                                            08:30
# 15                                           08:00
# 13                                           08:00
# 10                                           08:30
#
#    Thông thường bạn mất khoảng bao lâu để đi vào giấc ngủ đêm?  \
# 3                                      Ít hơn 15 phút
# 7                                          15-30 phút
# 15                                         15-30 phút
# 13                                         15-30 phút
# 10                                         15-30 phút
#
#    Thông thường giấc ngủ trưa của bạn kéo dài bao lâu?  \
# 3                                  Tôi không ngủ trưa
# 7                                  Tôi không ngủ trưa
# 15                                 Tôi không ngủ trưa
# 13                                 Tôi không ngủ trưa
# 10                                 Tôi không ngủ trưa
#
#    Trung bình mỗi ngày bạn ngủ bao nhiêu giờ trong một ngày (24 giờ)?  \
# 3                                           Hơn 6 giờ
# 7                                             4-6 giờ
# 15                                            4-6 giờ
# 13                                          Hơn 6 giờ
# 10                                          Hơn 6 giờ
#
#     Bạn đánh giá chất lượng giấc ngủ chung của mình như thế nào?  \
# 3                                                   5
# 7                                                   3
# 15                                                  2
# 13                                                  3
# 10                                                  4
#
#    Giấc ngủ của bạn có hay bị gián đoạn (vd: thức giấc nửa đêm, ngủ không yên) khong?  \
# 3                                            Hiếm khi
# 7                                        Thỉnh thoảng
# 15                                       Thỉnh thoảng
# 13                                       Thỉnh thoảng
# 10                                           Hiếm khi
#
#    Bạn có sử dụng bất kỳ loại thuốc nào để hỗ trợ giấc ngủ không?
# 3                                               Không
# 7                                               Không
# 15                                              Không
# 13                                              Không
# 10                                              Không

# %% [markdown]
# ### After

# %%
# Translate columns to English
vi_headers_dict = utils.read_json('translation/vi_header.json')

dfs['Vietnamese'].rename(columns=vi_headers_dict, inplace=True)

# Translate cell values to English
vi_cells_dict = utils.read_json('translation/vi_val.json')
utils.translate_cells(dfs["Vietnamese"], vi_cells_dict)

dfs["Vietnamese"]["Language"] = "Vietnamese"
dfs['Vietnamese'].sample(5)
# Out:
#                        Timestamp Age Group  Gender Education Level  \
# 1   2023/11/07 11:42:16 AM GMT+9     16-24    Male      Bachelor's
# 9    2023/11/07 2:22:13 PM GMT+9     25-34  Female        Master's
# 11   2023/11/07 5:18:05 PM GMT+9     25-34    Male        Master's
# 6   2023/11/07 12:43:54 PM GMT+9     25-34  Female      Bachelor's
# 5   2023/11/07 12:07:55 PM GMT+9     16-24    Male     High School
#
#                     Occupation Exercise Days/Week Device Usage (hrs/day)  \
# 1                      Student           1-2 Days               7+ Hours
# 9                      Student             0 Days              1-3 Hours
# 11  Professional/Office Worker           1-2 Days              1-3 Hours
# 6                      Student             0 Days               7+ Hours
# 5                      Student            5+ Days               7+ Hours
#
#    Screen Time Before Sleep  Height (cm)  Weight (kg) Bedtime Wake-up Time  \
# 1                  2+ Hours        175.0         65.0   12:15        08:00
# 9             30-60 Minutes        155.0          NaN   02:00        09:00
# 11              <30 Minutes        165.0         60.0   12:00        08:00
# 6               <30 Minutes        153.0         69.0   01:00        05:00
# 5               <30 Minutes          NaN          NaN   23:00        07:00
#
#    Sleep Onset Time   Nap Duration Sleep Duration (hrs/24hr)  Sleep Quality  \
# 1     30-60 Minutes  60-90 Minutes                  6+ Hours              4
# 9       <15 Minutes         No Nap                  6+ Hours              4
# 11    15-30 Minutes         No Nap                  6+ Hours              3
# 6       <15 Minutes  30-60 Minutes                 4-6 Hours              5
# 5     15-30 Minutes  30-60 Minutes                  6+ Hours              4
#
#    Sleep Disturbances Sleep Medication    Language
# 1           Sometimes               No  Vietnamese
# 9               Never               No  Vietnamese
# 11          Sometimes               No  Vietnamese
# 6               Never               No  Vietnamese
# 5              Rarely               No  Vietnamese

# %% [markdown]
# ## English

# %% [markdown]
# ### Before

# %%
dfs["English"].sample(5)
# Out:
#                        Timestamp What is your age group? What is your gender?  \
# 62   2023/11/09 3:23:19 PM GMT+9                   35-44                 Male
# 30  2023/11/08 10:13:25 AM GMT+9                   35-44               Female
# 37   2023/11/08 7:00:15 PM GMT+9                   45-54                 Male
# 7    2023/11/07 5:12:34 PM GMT+9                   25-34                 Male
# 25   2023/11/08 2:50:05 AM GMT+9                   25-34                 Male
#
#    What is the highest level of education you have completed?  \
# 62                                        High school
# 30                                    Master's degree
# 37                    Doctoral or professional degree
# 7                                   Bachelor's degree
# 25                                    Master's degree
#
#    Which category best describes your occupation?  \
# 62           Service (retail, food service, etc.)
# 30                        Professional/office job
# 37                        Professional/office job
# 7                                         Student
# 25                        Professional/office job
#
#    On average, how many days per week do you exercise for at least 30 (or under 30 mins but high intensity) minutes?   \
# 62                                             0 days
# 30                                             0 days
# 37                                           3-4 days
# 7                                      5 or more days
# 25                                           3-4 days
#
#    On average, how many hours per day do you use electronic devices such as smartphones, laptops, televisions, etc.?   \
# 62                                          1-3 hours
# 30                                    7 or more hours
# 37                                    7 or more hours
# 7                                           4-6 hours
# 25                                          4-6 hours
#
#    On average, how much time do you usually spend on phone / computers before sleep?  \
# 62                               Less than 30 minutes
# 30                                  More than 2 hours
# 37                                  More than 2 hours
# 7                                Less than 30 minutes
# 25                                30 minutes - 1 hour
#
#     (Optional) What is your height in centimeters?  \
# 62                                           180.0
# 30                                           150.0
# 37                                           180.0
# 7                                            172.0
# 25                                           172.0
#
#     (Optional) What is your weight in kilograms?  \
# 62                                          72.0
# 30                                          51.0
# 37                                          83.0
# 7                                           71.0
# 25                                          68.0
#
#    On average, what time do you typically go to bed at night?  \
# 62                                              11:00
# 30                                              02:00
# 37                                              23:30
# 7                                               23:30
# 25                                              23:00
#
#    On average, what time do you typically wake up in the morning?  \
# 62                                              06:00
# 30                                              04:30
# 37                                              07:00
# 7                                               06:30
# 25                                              07:30
#
#    On average, how long does it take you to fall asleep at night?  \
# 62                                      15-30 minutes
# 30                               More than 60 minutes
# 37                                      15-30 minutes
# 7                                       15-30 minutes
# 25                                      30-60 minutes
#
#    On average, how long is your typical daytime nap?  \
# 62                         Yes, less than 30 minutes
# 30                                Yes, 30-60 minutes
# 37                   No, I do not nap during the day
# 7                          Yes, less than 30 minutes
# 25                   No, I do not nap during the day
#
#    On average, how many hours do you sleep per 24-hour period?  \
# 62                                          4-6 hours
# 30                                          4-6 hours
# 37                                  More than 6 hours
# 7                                   More than 6 hours
# 25                                  More than 6 hours
#
#     How would you rate your overall sleep quality?  \
# 62                                               4
# 30                                               3
# 37                                               2
# 7                                                3
# 25                                               2
#
#    How often do you experience sleep disturbances such as waking up during the night or having restless sleep?  \
# 62                                             Rarely
# 30                                         Frequently
# 37                                         Frequently
# 7                                              Rarely
# 25                                         Frequently
#
#    Do you take any medication to help you sleep?
# 62                                            No
# 30                                            No
# 37                                            No
# 7                                             No
# 25                                            No

# %% [markdown]
# ### After

# %% [markdown]
# Even though the original survey data is in English, there are two problems:
# - Column headers contain long text, which decreases readablity.
# - Cell values also include long text, and unstandardized.

# %%
# Shorten column header texts
en_headers_dict = utils.read_json('translation/en_header.json')
dfs['English'].rename(columns=en_headers_dict, inplace=True)

# Translate cell values to English
en_cells_dict = utils.read_json('translation/en_val.json')
utils.translate_cells(dfs["English"], en_cells_dict)
dfs["English"]["Language"] = "English"
dfs["English"].sample(5)
# Out:
#                       Timestamp Age Group  Gender Education Level  \
# 55  2023/11/09 1:41:14 PM GMT+9     35-44    Male        Master's
# 10  2023/11/07 5:17:14 PM GMT+9     25-34  Female        Master's
# 17  2023/11/07 7:32:06 PM GMT+9     16-24  Female      Bachelor's
# 42  2023/11/08 8:24:28 PM GMT+9     35-44  Female        Master's
# 45  2023/11/09 1:04:38 AM GMT+9     35-44    Male       Doctorate
#
#                     Occupation Exercise Days/Week Device Usage (hrs/day)  \
# 55                     Student             0 Days               7+ Hours
# 10                     Student             0 Days              4-6 Hours
# 17                     Student            5+ Days              4-6 Hours
# 42  Professional/Office Worker             0 Days               7+ Hours
# 45  Professional/Office Worker           3-4 Days              1-3 Hours
#
#    Screen Time Before Sleep  Height (cm)  Weight (kg) Bedtime Wake-up Time  \
# 55            30-60 Minutes          NaN         72.0   13:30        07:30
# 10            30-60 Minutes        161.0         53.0   00:00        06:00
# 17              <30 Minutes        162.0         46.0   11:00        08:30
# 42                 2+ Hours        169.0         81.0   00:30        06:00
# 45              <30 Minutes        165.0         74.0   22:00        05:00
#
#    Sleep Onset Time Nap Duration Sleep Duration (hrs/24hr)  Sleep Quality  \
# 55    15-30 Minutes   30-60 mins                 4-6 Hours              2
# 10    15-30 Minutes     >90 mins                 4-6 Hours              4
# 17    15-30 Minutes   30-60 mins                  6+ Hours              3
# 42    15-30 Minutes       No Nap                 4-6 Hours              3
# 45      <15 Minutes     <30 mins                  6+ Hours              4
#
#    Sleep Disturbances Sleep Medication Language
# 55         Frequently               No  English
# 10              Never               No  English
# 17             Rarely               No  English
# 42          Sometimes               No  English
# 45          Sometimes               No  English

# %% [markdown]
# ## Korean

# %%
# Shorten column header texts
kr_headers_dict = utils.read_json('translation/kr_header.json')
dfs['Korean'].rename(columns=kr_headers_dict, inplace=True)

# Translate cell values to English
kr_cells_dict = utils.read_json('translation/kr_val.json')
utils.translate_cells(dfs["Korean"], kr_cells_dict)
dfs["Korean"]["Language"] = "Korean"
dfs["Korean"]
# Out:
#                       Timestamp Age Group  Gender Education Level Occupation  \
# 0  2023/11/07 11:29:18 AM GMT+9     16-24  Female     High School    Student
#
#   Exercise Days/Week Device Usage (hrs/day) Screen Time Before Sleep  \
# 0           1-2 Days               7+ Hours                1-2 Hours
#
#    Height (cm)  Weight (kg) Bedtime Wake-up Time Sleep Onset Time  \
# 0          167           60   01:00        08:30      <15 Minutes
#
#   Nap Duration Sleep Duration (hrs/24hr)  Sleep Quality Sleep Disturbances  \
# 0       No Nap                  6+ Hours              4          Sometimes
#
#   Sleep Medication Language
# 0               No   Korean

# %% [markdown]
# # Merge

# %%
df_merge = pd.concat(dfs.values())
df_merge.reset_index(inplace=True, drop=True)
df_merge.sample(5)
# Out:
#                       Timestamp Age Group  Gender Education Level  \
# 54  2023/11/09 1:18:51 PM GMT+9     35-44  Female        Master's
# 10  2023/11/07 5:17:14 PM GMT+9     25-34  Female        Master's
# 26  2023/11/08 8:06:42 AM GMT+9     25-34    Male       Doctorate
# 18  2023/11/07 8:13:13 PM GMT+9     25-34  Female        Master's
# 58  2023/11/09 1:45:22 PM GMT+9     35-44    Male      Bachelor's
#
#                     Occupation Exercise Days/Week Device Usage (hrs/day)  \
# 54  Professional/Office Worker           1-2 Days              4-6 Hours
# 10                     Student             0 Days              4-6 Hours
# 26  Professional/Office Worker           3-4 Days              4-6 Hours
# 18  Professional/Office Worker           1-2 Days              1-3 Hours
# 58  Professional/Office Worker           1-2 Days               7+ Hours
#
#    Screen Time Before Sleep  Height (cm)  Weight (kg) Bedtime Wake-up Time  \
# 54                 2+ Hours        150.0         70.0   22:00        06:00
# 10            30-60 Minutes        161.0         53.0   00:00        06:00
# 26                 2+ Hours        172.0         64.0   00:30        07:30
# 18            30-60 Minutes        154.0         63.0   00:30        07:00
# 58                1-2 Hours        155.0         72.0   23:00        06:00
#
#    Sleep Onset Time Nap Duration Sleep Duration (hrs/24hr)  Sleep Quality  \
# 54    15-30 Minutes     <30 mins                  6+ Hours              5
# 10    15-30 Minutes     >90 mins                 4-6 Hours              4
# 26      <15 Minutes       No Nap                  6+ Hours              3
# 18    30-60 Minutes     >90 mins                  6+ Hours              4
# 58    15-30 Minutes       No Nap                  6+ Hours              3
#
#    Sleep Disturbances Sleep Medication Language
# 54             Rarely               No  English
# 10              Never               No  English
# 26          Sometimes               No  English
# 18          Sometimes               No  English
# 58             Rarely               No  English

# %%
df_merge.describe()
# Out:
#        Height (cm)  Weight (kg)  Sleep Quality
# count    89.000000    92.000000     108.000000
# mean    157.569551    67.415217       3.444444
# std      30.981275    12.798085       0.824092
# min       5.110000    43.000000       2.000000
# 25%     155.000000    59.800000       3.000000
# 50%     165.000000    68.000000       3.000000
# 75%     171.000000    75.000000       4.000000
# max     185.000000   100.000000       5.000000

# %% [markdown]
# There are twos outlier where height are under 100 (cm). To be safe, I'll replace these values with NaN

# %%
import numpy as np
df_merge['Height (cm)'] = df_merge['Height (cm)'].apply(lambda x: np.nan if x < 100 else x)
df_merge.describe()
# Out:
#        Height (cm)  Weight (kg)  Sleep Quality
# count    83.000000    92.000000     108.000000
# mean    165.305542    67.415217       3.444444
# std       8.321679    12.798085       0.824092
# min     150.000000    43.000000       2.000000
# 25%     160.000000    59.800000       3.000000
# 50%     167.000000    68.000000       3.000000
# 75%     171.000000    75.000000       4.000000
# max     185.000000   100.000000       5.000000

# %% [markdown]
# Let's add BMI index, which could be a helpful indicator for health

# %%
def calculate_bmi(weight, height_cm):
    if pd.notnull(weight) and pd.notnull(height_cm):
        height_m = height_cm / 100.0  # Convert height from cm to m
        bmi = weight / (height_m ** 2)
        return round(bmi,1)
    else:
        return None  # Return None if weight or height is missing
    
df_merge['BMI'] = df_merge.apply(lambda row: calculate_bmi(row['Weight (kg)'], row['Height (cm)']), axis=1)
df_merge.describe()
# Out:
#        Height (cm)  Weight (kg)  Sleep Quality        BMI
# count    83.000000    92.000000     108.000000  80.000000
# mean    165.305542    67.415217       3.444444  24.552500
# std       8.321679    12.798085       0.824092   4.245503
# min     150.000000    43.000000       2.000000  17.500000
# 25%     160.000000    59.800000       3.000000  21.500000
# 50%     167.000000    68.000000       3.000000  23.550000
# 75%     171.000000    75.000000       4.000000  26.600000
# max     185.000000   100.000000       5.000000  39.400000

# %% [markdown]
# Calculate Sleep Duration to compare with self-reported value in later analysis

# %%
from datetime import datetime, timedelta

# Function to parse time considering the day might change over midnight
def parse_time(time_str):
    # Assuming the time format is "HH:MM"
    return datetime.strptime(time_str, "%H:%M").time()

# Function to calculate sleep duration
def calculate_sleep_duration(bedtime_str, wakeup_str):
    bedtime = parse_time(bedtime_str)
    wakeup = parse_time(wakeup_str)
    
    # Convert to datetime objects
    bedtime_dt = datetime.combine(datetime.today(), bedtime)
    wakeup_dt = datetime.combine(datetime.today(), wakeup)
    
    # If bedtime is later than wakeup time, assume sleeping past midnight
    if bedtime_dt > wakeup_dt:
        wakeup_dt += timedelta(days=1)
    
    # Calculate the duration and convert to hours
    duration = wakeup_dt - bedtime_dt
    return round((duration.total_seconds() / 3600 ),2) # convert seconds to hours

# Apply the function to each row in the DataFrame
df_merge['Calculated Night Sleep Duration'] = df_merge.apply(lambda x: calculate_sleep_duration(x['Bedtime'], x['Wake-up Time']), axis=1)
df_merge.describe()
# Out:
#        Height (cm)  Weight (kg)  Sleep Quality        BMI  \
# count    83.000000    92.000000     108.000000  80.000000
# mean    165.305542    67.415217       3.444444  24.552500
# std       8.321679    12.798085       0.824092   4.245503
# min     150.000000    43.000000       2.000000  17.500000
# 25%     160.000000    59.800000       3.000000  21.500000
# 50%     167.000000    68.000000       3.000000  23.550000
# 75%     171.000000    75.000000       4.000000  26.600000
# max     185.000000   100.000000       5.000000  39.400000
#
#        Calculated Night Sleep Duration
# count                       108.000000
# mean                          9.793981
# std                           5.497084
# min                           1.670000
# 25%                           6.500000
# 50%                           7.500000
# 75%                           9.000000
# max                          23.950000

# %% [markdown]
# Possible Data Error: Calculate sleep duration have some values over 14 hours

# %%
df_merge.sort_values(by="Calculated Night Sleep Duration", ascending=False)[['Bedtime', 'Wake-up Time', 'Calculated Night Sleep Duration']]
# Out:
#    Bedtime Wake-up Time  Calculated Night Sleep Duration
# 23   19:23        19:20                            23.95
# 19   00:12        00:07                            23.92
# 17   11:00        08:30                            21.50
# 78   11:00        08:30                            21.50
# 5    11:00        08:00                            21.00
# ..     ...          ...                              ...
# 4    01:00        05:30                             4.50
# 98   01:00        05:00                             4.00
# 20   01:00        05:00                             4.00
# 30   02:00        04:30                             2.50
# 86   02:20        04:00                             1.67
#
# [108 rows x 3 columns]

# %% [markdown]
# Some people may confuse AM / PM and 24-hour format. For example:

# %%
df_merge[df_merge['Calculated Night Sleep Duration'] > 12]["Bedtime"].unique()
# Out:
# array(['12:30', '11:00', '10:00', '00:12', '04:00', '19:23', '12:00',
#        '10:30', '09:30', '13:30', '13:00', '12:15'], dtype=object)

# %% [markdown]
# The survey is conducted using 24-hour format. So, if a person sleeps at 11PM, he/she should enter 23:00 instead of 11:00, which could be case there.
# I'll create a function to add 12 hours to their input, except for the "4:00" bed-time above.

# %%
def fix_bedtime(bedtime_str):
    bedtime = parse_time(bedtime_str)
    
    # Convert to datetime objects
    bedtime_dt = datetime.combine(datetime.today(), bedtime)
    
    # If bedtime is later than wakeup time, assume sleeping past midnight
    if bedtime_dt > datetime.combine(datetime.today(), parse_time("9:00")) and bedtime_dt < datetime.combine(datetime.today(), parse_time("19:00")):
        bedtime_dt += timedelta(hours=12)

    return bedtime_dt.strftime("%H:%M")

# Fix the bedtime
df_merge['Bedtime'] = df_merge.apply(lambda x: fix_bedtime(x['Bedtime']), axis=1)
# # Recalculate bedtime
df_merge['Calculated Night Sleep Duration'] = df_merge.apply(lambda x: calculate_sleep_duration(x['Bedtime'], x['Wake-up Time']), axis=1)
# # Check for outliers
df_merge.sort_values(by="Calculated Night Sleep Duration", ascending=False)[['Bedtime', 'Wake-up Time', 'Calculated Night Sleep Duration']]
# Out:
#    Bedtime Wake-up Time  Calculated Night Sleep Duration
# 23   19:23        19:20                            23.95
# 19   00:12        00:07                            23.92
# 21   04:00        23:00                            19.00
# 74   22:00        07:45                             9.75
# 17   23:00        08:30                             9.50
# ..     ...          ...                              ...
# 57   00:00        04:00                             4.00
# 98   01:00        05:00                             4.00
# 20   01:00        05:00                             4.00
# 30   02:00        04:30                             2.50
# 86   02:20        04:00                             1.67
#
# [108 rows x 3 columns]

# %% [markdown]
# There are still 3 strange values at the top, while the majority is now normal.
#
# Let's NaN those values and save the data to csv

# %%
df_merge["Calculated Night Sleep Duration"] = df_merge["Calculated Night Sleep Duration"].apply(lambda x: x if x < 10 else np.nan)
df_merge.to_csv('data/all.csv', index=False)
